# %% [markdown]
# Análisis de gasto común

# %%
#Importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
#Leer archivo
gc_df = pd.read_csv('../Archivos CSV/GASTO_COMUN.csv')

# %%
#Información del archivo
gc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FOLIO                      10 non-null     object
#  1   MES DE COBRO               10 non-null     object
#  2   ANIO                       10 non-null     int64
#  3   DESDE                      10 non-null     object
#  4   HASTA                      10 non-null     object
#  5   GASTO COMUN EDIFICIO       10 non-null     object
#  6   GASTO COMUN                10 non-null     float64
#  7   FONDO DE RESERVA           10 non-null     float64
#  8   SEGURO UNIDAD COPROPIEDAD  9 non-null      float64
#  9   AGUA INDIVIDUAL            10 non-null     float64
#  10  COMBUSTIBLE                9 non-null      float64
#  11  OTROS COBROS               1 non-null      float64
#  12  70% BOL GAS                10 non-null     object
#  13  VALOR TOTAL M3             10 non-null     float64
#  14  TOTAL A PAGAR              10 non-null     float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
#Visualización df
gc_df
# Out:
#      FOLIO MES DE COBRO  ANIO       DESDE       HASTA GASTO COMUN EDIFICIO
# 0  13-3400        Junio  2023  31-05-2023  30-06-2023           18.527.884  \
# 1  14-3676        Julio  2023  30-06-2023  31-07-2023           16.185.498
# 2  15-3952       Agosto  2023  31-07-2023  31-08-2023           16.332.521
# 3  16-4228   Septiembre  2023  31-08-2023  30-09-2023           18.857.327
# 4  17-4504      Octubre  2023  30-09-2023  31-10-2023           16.427.727
# 5  18-4781    Novimebre  2023  31-10-2023  30-11-2023           16.780.025
# 6  19-5058    Diciembre  2023  30-11-2023  30-12-2023           18.852.989
# 7  20-5335        Enero  2024  31-12-2023  31-01-2024           17.606.243
# 8  21-5612      Febrero  2024  31-01-2024  29-02-2024           15.698.655
# 9  22-5889        Marzo  2024  29-02-2024  31-03-2024           16.037.148
#
#    GASTO COMUN  FONDO DE RESERVA  SEGURO UNIDAD COPROPIEDAD  AGUA INDIVIDUAL
# 0       57.603             2.880                      2.558            6.659  \
# 1       50.321             2.516                      2.558            5.382
# 2       50.778             2.539                      2.558            5.929
# 3       58.627             2.931                      2.558            6.727
# 4       51.074             2.554                        NaN            7.095
# 5       52.169             2.608                      2.558            8.387
# 6       58.614             2.931                      2.558            9.056
# 7       54.738             2.737                      2.558            6.643
# 8       48.807             2.440                      2.558            7.453
# 9       49.859             2.493                      2.558            6.123
#
#    COMBUSTIBLE  OTROS COBROS 70% BOL GAS  VALOR TOTAL M3  TOTAL A PAGAR
# 0       24.203           NaN   4.394.514           6.172         93.903
# 1       20.220           NaN   4.633.712           6.401         80.997
# 2       18.815           NaN   4.229.931           6.186         80.619
# 3       27.595           NaN   4.835.706           6.864         98.438
# 4       23.807           NaN   4.104.248           6.180         84.530
# 5       32.294           NaN   4.202.639           6.780         98.016
# 6       26.455           NaN   4.031.137           7.102         99.614
# 7       20.841           NaN   3.266.748           6.871         87.517
# 8          NaN           NaN   2.964.717           7.578         61.258
# 9       24.628        22.861   3.477.307           6.150        108.522

# %%
# Convertir columnas a datetime
gc_df["DESDE"] = pd.to_datetime(gc_df["DESDE"])
gc_df["HASTA"] = pd.to_datetime(gc_df["HASTA"])
# Out:
# C:\Users\manee\AppData\Local\Temp\ipykernel_30104\3192547614.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   gc_df["DESDE"] = pd.to_datetime(gc_df["DESDE"])
# C:\Users\manee\AppData\Local\Temp\ipykernel_30104\3192547614.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   gc_df["HASTA"] = pd.to_datetime(gc_df["HASTA"])

# %%
#Eliminar puntos y convertir a flotante la columna "GASTO COMUN EDIFICIO"
gc_df["GASTO COMUN EDIFICIO"] = gc_df["GASTO COMUN EDIFICIO"].str.replace(".", "").astype(float) / 1000000

#Eliminar puntos y convertir a flotante la columna "70% BOL GAS"
gc_df["70% BOL GAS"] = gc_df["70% BOL GAS"].str.replace(".", "").astype(float) / 1000000

# %%
gc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FOLIO                      10 non-null     object
#  1   MES DE COBRO               10 non-null     object
#  2   ANIO                       10 non-null     int64
#  3   DESDE                      10 non-null     datetime64[ns]
#  4   HASTA                      10 non-null     datetime64[ns]
#  5   GASTO COMUN EDIFICIO       10 non-null     float64
#  6   GASTO COMUN                10 non-null     float64
#  7   FONDO DE RESERVA           10 non-null     float64
#  8   SEGURO UNIDAD COPROPIEDAD  9 non-null      float64
#  9   AGUA INDIVIDUAL            10 non-null     float64
#  10  COMBUSTIBLE                9 non-null      float64
#  11  OTROS COBROS               1 non-null      float64
#  12  70% BOL GAS                10 non-null     float64
#  13  VALOR TOTAL M3             10 non-null     float64
#  14  TOTAL A PAGAR              10 non-null     float64
# dtypes: datetime64[ns](2), float64(10), int64(1), object(2)
# memory usage: 1.3+ KB

# %%
#Línea de tendencia
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=gc_df, x='DESDE', y='TOTAL A PAGAR', marker='o', markersize=8, color='b', label='Total a Pagar (CLP)')
plt.title('Tendencia del Total a Pagar a lo largo del Tiempo')
plt.xlabel('Fecha de Cobro')
plt.ylabel('Total a Pagar (CLP)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

for x, y, total in zip(gc_df['DESDE'], gc_df['TOTAL A PAGAR'], gc_df['TOTAL A PAGAR']):
    plt.annotate(f'{total}', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=10)

plt.legend()
plt.show()

# %%
#Gastos comunes de mi hermano
gc_brother_df = pd.read_csv('../Archivos CSV/GASTO_COMUN_BROTHER.csv')

# %%
#Visualizar df
gc_brother_df.head()
# Out:
#   FECHA DE PAGO  TOTAL A PAGAR
# 0    30-07-2022          75956
# 1    01-09-2022          70384
# 2    01-10-2022          68270
# 3    02-11-2022          74956
# 4    26-11-2022          64479

# %%
#Información del df
gc_brother_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FECHA DE PAGO  11 non-null     object
#  1   TOTAL A PAGAR  11 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 304.0+ bytes

# %%
#Pasar a datetime la fecha de pago
gc_brother_df["FECHA DE PAGO"] = pd.to_datetime(gc_brother_df["FECHA DE PAGO"], dayfirst=True)

# %%
gc_brother_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FECHA DE PAGO  11 non-null     datetime64[ns]
#  1   TOTAL A PAGAR  11 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 304.0 bytes

# %%
gc_brother_df = gc_brother_df.sort_values(by='FECHA DE PAGO')

# %%
#Linea de tendencia de mi hermano
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(x="FECHA DE PAGO", y="TOTAL A PAGAR", data=gc_brother_df, marker='o')
plt.xticks(rotation=45)
plt.xlabel('Fecha de pago')
plt.ylabel('Total a pagar (CLP)')
plt.title('Pagos de mi hermano a lo largo del tiempo')
plt.grid(True)
plt.tight_layout()
for x, y, total in zip(gc_brother_df['FECHA DE PAGO'], gc_brother_df['TOTAL A PAGAR'], gc_brother_df['TOTAL A PAGAR']):
    plt.annotate(f'{total}', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=10)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Unir df para coincidir datos

# %%
#Renombrar columnas para que coincidan con el otro DataFrame
gc_df.rename(columns={'DESDE': 'FECHA DE PAGO'}, inplace=True)

# %%
#Unir los DataFrames en función de la fecha de pago
merged_df = pd.merge(gc_df, gc_brother_df, on='FECHA DE PAGO', how='inner')

# %%
#Ver la unión
merged_df.head()
# Out:
# Empty DataFrame
# Columns: [FOLIO, MES DE COBRO, ANIO, FECHA DE PAGO, HASTA, GASTO COMUN EDIFICIO, GASTO COMUN, FONDO DE RESERVA, SEGURO UNIDAD COPROPIEDAD, AGUA INDIVIDUAL, COMBUSTIBLE, OTROS COBROS, 70% BOL GAS, VALOR TOTAL M3, TOTAL A PAGAR_x, TOTAL A PAGAR_y]
# Index: []
